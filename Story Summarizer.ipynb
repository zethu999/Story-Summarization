# %%
! pip install SpeechRecognition
! pip install pydub
! pip install google-cloud-speech
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SpeechRecognition in /usr/local/lib/python3.7/dist-packages (3.8.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (0.25.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-cloud-speech in /usr/local/lib/python3.7/dist-packages (2.16.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-speech) (1.22.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-speech) (4.21.8)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-speech) (2.10.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (2.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (1.56.4)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (1.35.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (1.50.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (1.50.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (4.2.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech) (2022.9.24)

# %%
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
path = "final.wav"

text = get_large_audio_transcription(path);
print("\nFull text:", text)
# Out:
# audio-chunks/chunk1.wav : Section 49 at the art of public speaking this is a librivox recording.
# audio-chunks/chunk2.wav : Only provoked recording from the public tonight.
# audio-chunks/chunk3.wav : More information or to volunteer.
# audio-chunks/chunk4.wav : Please present librivox.org.
# audio-chunks/chunk5.wav : Recording by paul adams.
# audio-chunks/chunk6.wav : The office of public speaking by dale carnegie and joseph bookcase and wine.
# audio-chunks/chunk7.wav : Section 49.
# audio-chunks/chunk8.wav : Appendix d.
# audio-chunks/chunk9.wav : Speeches for study and practice.
# audio-chunks/chunk10.wav : Victor hugo honore de balzac.
# audio-chunks/chunk11.wav : Delivered at the funeral of balance at august 20th.
# audio-chunks/chunk12.wav : 1850.
# audio-chunks/chunk13.wav : Gentleman.
# audio-chunks/chunk14.wav : The man who now goes down into this tube is one of those to whom public queef pays homage.
# audio-chunks/chunk15.wav : In one day all fictions have vanished.
# audio-chunks/chunk16.wav : Bianca is fixed not only on the heads that right.
# audio-chunks/chunk17.wav : Put on the headset think.
# audio-chunks/chunk18.wav : The whole country is moved when one of those heads disappears.
# audio-chunks/chunk19.wav : Today we have a people in black because of the death of the man of talent.
# audio-chunks/chunk20.wav : Nation in mourning for a man of genius.
# audio-chunks/chunk21.wav : Gentleman.
# audio-chunks/chunk22.wav : The name of bowser will be mingled in the luminous trace epochal leave across the future.
# audio-chunks/chunk23.wav : Bounce with one powerful generation of rice's of the nineteenth century who came often the polian.
# audio-chunks/chunk24.wav : As the industrious play out of the 17th century came off to reflow.
# audio-chunks/chunk25.wav : Ziff in the development of civilization there ever a law which gives conquerors by the insects as successes to congress by the sword.
# audio-chunks/chunk26.wav : Balance act was one of the first among the greatest one of the highest among the best.
# audio-chunks/chunk27.wav : This is not the place to tell old constituted the splendid and sovereign intelligence.
# audio-chunks/chunk28.wav : What was his books for one book.
# audio-chunks/chunk29.wav : A book living luminous profound where once he's coming and going and marching and moving with i know not w of the formalin terrible mixed with the real hold a contemporary civilization.
# audio-chunks/chunk30.wav : Obelisk book which the poet entitled up comedy.
# audio-chunks/chunk31.wav : I wish you could have called history which takes all forms and all styles which surpasses tacitus from suetonius.
# audio-chunks/chunk32.wav : A book which realizes observation and imagination which lavishes the truth the esoteric the commonplace the trivial the material hundreds of times through ola rihanna's his swiftly and grandly rental.
# audio-chunks/chunk33.wav : The most somber and tragic ideal.
# audio-chunks/chunk34.wav : Unknown to himself.
# audio-chunks/chunk35.wav : Whether he wished it or not whether he consented or not.
# audio-chunks/chunk36.wav : The author of this immense and strange work.
# audio-chunks/chunk37.wav : Is one of the strong race of revolutionist rice's.
# audio-chunks/chunk38.wav : Bounce that goes straight to the goal.
# audio-chunks/chunk39.wav : Body to body he sees his modern society from old he wrecked something.
# audio-chunks/chunk40.wav : From these an illusion from those of hope from wanna catch words from another amount.
# audio-chunks/chunk41.wav : He ransacked vice he dissected passion.
# audio-chunks/chunk42.wav : He sucked out and sounded man so hot and trails brain the abyss that each one has within himself.
# audio-chunks/chunk43.wav : I'm by grace of his free and vigorous nature by a privilege of the intellect about time which having seen revolutions face-to-face can see more clearly the destiny of humanity.
# audio-chunks/chunk44.wav : And comprehend providence plaza.
# audio-chunks/chunk45.wav : Belzak redeem himself smiling and severe from those formidable studies which produced melancholy and molly are on misanthropy in russo.
# audio-chunks/chunk46.wav : This is what he has accomplished among us this is the work which he has left us a walk lost it and solid.
# audio-chunks/chunk47.wav : A monument robustly piled in layers of granite.
# audio-chunks/chunk48.wav : From the heights of which hair after his renowned shells shine in splenda.
# audio-chunks/chunk49.wav : Great men make their own pedestal.
# audio-chunks/chunk50.wav : The future will be answerable for the statue.
# audio-chunks/chunk51.wav : His death stupefied paris.
# audio-chunks/chunk52.wav : Only a few months ago he had to come back to france feeling that he was dying he wish to see his country again as one who would embrace his mother on the 8th of a distant voyage.
# audio-chunks/chunk53.wav : His life was short but full.
# audio-chunks/chunk54.wav : More filled with beads and days.
# audio-chunks/chunk55.wav : This powerful worker never fatigued this philosopher this finca this poet this genius has lived among us that life of strife her clothes and come back, in all times to all great men.
# audio-chunks/chunk56.wav : Today.
# audio-chunks/chunk57.wav : He is at peace.
# audio-chunks/chunk58.wav : He escapes contention and hatred.
# audio-chunks/chunk59.wav : On the same day he enters into glory.
erful generation of rice s of the nineteenth century who came often the polian as the industrious play out of the th century came off to reflow ziff in the development of civilization there ever a law which gives conquerors by the insects as successes to congress by the sword balance act was one of the first among the greatest one of the highest among the best this is not the place to tell old constituted the splendid and sovereign intelligence what was his books for one book a book living luminous profound where once he s coming and going and marching and moving with i know not w of the formalin terrible mixed with the real hold a contemporary civilization obelisk book which the poet entitled up comedy i wish you could have called history which takes all forms and all styles which surpasses tacitus from suetonius a book which realizes observation and imagination which lavishes the truth the esoteric the commonplace the trivial the material hundreds of times through ola rihanna s his swiftly and grandly rental the most somber and tragic ideal unknown to himself whether he wished it or not whether he consented or not the author of this immense and strange work is one of the strong race of revolutionist rice s bounce that goes straight to the goal body to body he sees his modern society from old he wrecked something from these an illusion from those of hope from wanna catch words from another amount he ransacked vice he dissected passion he sucked out and sounded man so hot and trails brain the abyss that each one has within himself i m by grace of his free and vigorous nature by a privilege of the intellect about time which having seen revolutions face to face can see more clearly the destiny of humanity and comprehend providence plaza belzak redeem himself smiling and severe from those formidable studies which produced melancholy and molly are on misanthropy in russo this is what he has accomplished among us this is the work which he has left us a walk lost it and solid a monument robustly piled in layers of granite from the heights of which hair after his renowned shells shine in splenda great men make their own pedestal the future will be answerable for the statue his death stupefied paris only a few months ago he had to come back to france feeling that he was dying he wish to see his country again as one who would embrace his mother on the th of a distant voyage his life was short but full more filled with beads and days this powerful worker never fatigued this philosopher this finca this poet this genius has lived among us that life of strife her clothes and come back in all times to all great men today he is at peace he escapes contention and hatred on the same day he enters into glory and the tube they re off to beyond the clouds which were above our heads he will shine among the stars of his country or you who are here are you not tempted to envy him whatever maybe a griffin presents of sasha lost let us accept these catastrophes with resignation let us accept in it whatever is distressing and severe it is good perhaps it is n ...

# %%
sentence_list = sentence_lower.split()
sentence_list
# Out:
# ['section',
#  'at',
#  'the',
#  'art',
#  'of',
#  'public',
#  'speaking',
#  'this',
#  'is',
#  'a',
#  'librivox',
#  'recording',
#  'only',
#  'provoked',
#  'recording',
#  'from',
#  'the',
#  'public',
#  'tonight',
#  'more',
#  'information',
#  'or',
#  'to',
#  'volunteer',
#  'please',
#  'present',
#  'librivox',
#  'org',
#  'recording',
#  'by',
#  'paul',
#  'adams',
#  'the',
#  'office',
#  'of',
#  'public',
#  'speaking',
#  'by',
#  'dale',
#  'carnegie',
#  'and',
#  'joseph',
#  'bookcase',
#  'and',
#  'wine',
#  'section',
#  'appendix',
#  'd',
#  'speeches',
#  'for',
#  'study',
#  'and',
#  'practice',
#  'victor',
#  'hugo',
#  'honore',
#  'de',
#  'balzac',
#  'delivered',
#  'at',
#  'the',
#  'funeral',
#  'of',
#  'balance',
#  'at',
#  'august',
#  'th',
#  'gentleman',
#  'the',
#  'man',
#  'who',
#  'now',
#  'goes',
#  'down',
#  'into',
#  'this',
#  'tube',
#  'is',
#  'one',
#  'of',
#  'those',
#  'to',
#  'whom',
#  'public',
#  'queef',
#  'pays',
#  'homage',
#  'in',
#  'one',
#  'day',
#  'all',
#  'fictions',
#  'have',
#  'vanished',
#  'bianca',
#  'is',
#  'fixed',
#  'not',
#  'only',
#  'on',
#  'the',
#  'heads',
#  'that',
#  'right',
#  'put',
#  'on',
#  'the',
#  'headset',
#  'think',
#  'the',
#  'whole',
#  'country',
#  'is',
#  'moved',
#  'when',
#  'one',
#  'of',
#  'those',
#  'heads',
#  'disappears',
#  'today',
#  'we',
#  'have',
#  'a',
#  'people',
#  'in',
#  'black',
#  'because',
#  'of',
#  'the',
#  'death',
#  'of',
#  'the',
#  'man',
#  'of',
#  'talent',
#  'nation',
#  'in',
#  'mourning',
#  'for',
#  'a',
#  'man',
#  'of',
#  'genius',
#  'gentleman',
#  'the',
#  'name',
#  'of',
#  'bowser',
#  'will',
#  'be',
#  'mingled',
#  'in',
#  'the',
#  'luminous',
#  'trace',
#  'epochal',
#  'leave',
#  'across',
#  'the',
#  'future',
#  'bounce',
#  'with',
#  'one',
#  'powerful',
#  'generation',
#  'of',
#  'rice',
#  's',
#  'of',
#  'the',
#  'nineteenth',
#  'century',
#  'who',
#  'came',
#  'often',
#  'the',
#  'polian',
#  'as',
#  'the',
#  'industrious',
#  'play',
#  'out',
#  'of',
#  'the',
#  'th',
#  'century',
#  'came',
#  'off',
#  'to',
#  'reflow',
#  'ziff',
#  'in',
#  'the',
#  'development',
#  'of',
#  'civilization',
#  'there',
#  'ever',
#  'a',
#  'law',
#  'which',
#  'gives',
#  'conquerors',
#  'by',
#  'the',
#  'insects',
#  'as',
#  'successes',
#  'to',
#  'congress',
#  'by',
#  'the',
#  'sword',
#  'balance',
#  'act',
#  'was',
#  'one',
#  'of',
#  'the',
#  'first',
#  'among',
#  'the',
#  'greatest',
#  'one',
#  'of',
#  'the',
#  'highest',
#  'among',
#  'the',
#  'best',
#  'this',
#  'is',
#  'not',
#  'the',
#  'place',
#  'to',
#  'tell',
#  'old',
#  'constituted',
#  'the',
#  'splendid',
#  'and',
#  'sovereign',
#  'intelligence',
#  'what',
#  'was',
#  'his',
#  'books',
#  'for',
#  'one',
#  'book',
#  'a',
#  'book',
#  'living',
#  'luminous',
#  'profound',
#  'where',
#  'once',
#  'he',
#  's',
#  'coming',
#  'and',
#  'going',
#  'and',
#  'marching',
#  'and',
#  'moving',
#  'with',
#  'i',
#  'know',
#  'not',
#  'w',
#  'of',
#  'the',
#  'formalin',
#  'terrible',
#  'mixed',
#  'with',
#  'the',
#  'real',
#  'hold',
#  'a',
#  'contemporary',
#  'civilization',
#  'obelisk',
#  'book',
#  'which',
#  'the',
#  'poet',
#  'entitled',
#  'up',
#  'comedy',
#  'i',
#  'wish',
#  'you',
#  'could',
#  'have',
#  'called',
#  'history',
#  'which',
#  'takes',
#  'all',
#  'forms',
#  'and',
#  'all',
#  'styles',
#  'which',
#  'surpasses',
#  'tacitus',
#  'from',
#  'suetonius',
#  'a',
#  'book',
#  'which',
#  'realizes',
#  'observation',
#  'and',
#  'imagination',
#  'which',
#  'lavishes',
#  'the',
#  'truth',
#  'the',
#  'esoteric',
#  'the',
#  'commonplace',
#  'the',
#  'trivial',
#  'the',
#  'material',
#  'hundreds',
#  'of',
#  'times',
#  'through',
#  'ola',
#  'rihanna',
#  's',
#  'his',
#  'swiftly',
#  'and',
#  'grandly',
#  'rental',
#  'the',
#  'most',
#  'somber',
#  'and',
#  'tragic',
#  'ideal',
#  'unknown',
#  'to',
#  'himself',
#  'whether',
#  'he',
#  'wished',
#  'it',
#  'or',
#  'not',
#  'whether',
#  'he',
#  'consented',
#  'or',
#  'not',
#  'the',
#  'author',
#  'of',
#  'this',
#  'immense',
#  'and',
#  'strange',
#  'work',
#  'is',
#  'one',
#  'of',
#  'the',
#  'strong',
#  'race',
#  'of',
#  'revolutionist',
#  'rice',
#  's',
#  'bounce',
#  'that',
#  'goes',
#  'straight',
#  'to',
#  'the',
#  'goal',
#  'body',
#  'to',
#  'body',
#  'he',
#  'sees',
#  'his',
#  'modern',
#  'society',
#  'from',
#  'old',
#  'he',
#  'wrecked',
#  'something',
#  'from',
#  'these',
#  'an',
#  'illusion',
#  'from',
#  'those',
#  'of',
#  'hope',
#  'from',
#  'wanna',
#  'catch',
#  'words',
#  'from',
#  'another',
#  'amount',
#  'he',
#  'ransacked',
#  'vice',
#  'he',
#  'dissected',
#  'passion',
#  'he',
#  'sucked',
#  'out',
#  'and',
#  'sounded',
#  'man',
#  'so',
#  'hot',
#  'and',
#  'trails',
#  'brain',
#  'the',
#  'abyss',
#  'that',
#  'each',
#  'one',
#  'has',
#  'within',
#  'himself',
#  'i',
#  'm',
#  'by',
#  'grace',
#  'of',
#  'his',
#  'free',
#  'and',
#  'vigorous',
#  'nature',
#  'by',
#  'a',
#  'privilege',
#  'of',
#  'the',
#  'intellect',
#  'about',
#  'time',
#  'which',
#  'having',
#  'seen',
#  'revolutions',
#  'face',
#  'to',
#  'face',
#  'can',
#  'see',
#  'more',
#  'clearly',
#  'the',
#  'destiny',
#  'of',
#  'humanity',
#  'and',
#  'comprehend',
#  'providence',
#  'plaza',
#  'belzak',
#  'redeem',
#  'himself',
#  'smiling',
#  'and',
#  'severe',
#  'from',
#  'those',
#  'formidable',
#  'studies',
#  'which',
#  'produced',
#  'melancholy',
#  'and',
#  'molly',
#  'are',
#  'on',
#  'misanthropy',
#  'in',
#  'russo',
#  'this',
#  'is',
#  'what',
#  'he',
#  'has',
#  'accomplished',
#  'among',
#  'us',
#  'this',
#  'is',
#  'the',
#  'work',
#  'which',
#  'he',
#  'has',
#  'left',
#  'us',
#  'a',
#  'walk',
#  'lost',
#  'it',
#  'and',
#  'solid',
#  'a',
#  'monument',
#  'robustly',
#  'piled',
#  'in',
#  'layers',
#  'of',
#  'granite',
#  'from',
#  'the',
#  'heights',
#  'of',
#  'which',
#  'hair',
#  'after',
#  'his',
#  'renowned',
#  'shells',
#  'shine',
#  'in',
#  'splenda',
#  'great',
#  'men',
#  'make',
#  'their',
#  'own',
#  'pedestal',
#  'the',
#  'future',
#  'will',
#  'be',
#  'answerable',
#  'for',
#  'the',
#  'statue',
#  'his',
#  'death',
#  'stupefied',
#  'paris',
#  'only',
#  'a',
#  'few',
#  'months',
#  'ago',
#  'he',
#  'had',
#  'to',
#  'come',
#  'back',
#  'to',
#  'france',
#  'feeling',
#  'that',
#  'he',
#  'was',
#  'dying',
#  'he',
#  'wish',
#  'to',
#  'see',
#  'his',
#  'country',
#  'again',
#  'as',
#  'one',
#  'who',
#  'would',
#  'embrace',
#  'his',
#  'mother',
#  'on',
#  'the',
#  'th',
#  'of',
#  'a',
#  'distant',
#  'voyage',
#  'his',
#  'life',
#  'was',
#  'short',
#  'but',
#  'full',
#  'more',
#  'filled',
#  'with',
#  'beads',
#  'and',
#  'days',
#  'this',
#  'powerful',
#  'worker',
#  'never',
#  'fatigued',
#  'this',
#  'philosopher',
#  'this',
#  'finca',
#  'this',
#  'poet',
#  'this',
#  'genius',
#  'has',
#  'lived',
#  'among',
#  'us',
#  'that',
#  'life',
#  'of',
#  'strife',
#  'her',
#  'clothes',
#  'and',
#  'come',
#  'back',
#  'in',
#  'all',
#  'times',
#  'to',
#  'all',
#  'great',
#  'men',
#  'today',
#  'he',
#  'is',
#  'at',
#  'peace',
#  'he',
#  'escapes',
#  'contention',
#  'and',
#  'hatred',
#  'on',
#  'the',
#  'same',
#  'day',
#  'he',
#  'enters',
#  'into',
#  'glory',
#  'and',
#  'the',
#  'tube',
#  'they',
#  're',
#  'off',
#  'to',
#  'beyond',
#  'the',
#  'clouds',
#  'which',
#  'were',
#  'above',
#  'our',
#  'heads',
#  'he',
#  'will',
#  'shine',
#  'among',
#  'the',
#  'stars',
#  'of',
#  'his',
#  'country',
#  'or',
#  'you',
#  'who',
#  'are',
#  'here',
#  'are',
#  'you',
#  'not',
#  'tempted',
#  'to',
#  'envy',
#  'him',
#  'whatever',
#  'maybe',
#  'a',
#  'griffin',
#  'presents',
#  'of',
#  'sasha',
#  'lost',
#  'let',
#  'us',
#  'accept',
#  'these',
#  'catastrophes',
#  'with',
#  'resignation',
#  'let',
#  'us',
#  'accept',
#  'in',
#  'it',
#  'whatever',
#  'is',
#  'distressing',
#  'and',
#  'severe',
#  'it',
#  'is',
#  'good',
#  'perhaps',
#  'it',
#  'is',
#  'necessary',
#  'perhaps',
#  'in',
#  'a',
#  'teapot',
#  'like',
#  'how',
#  'is',
#  'that',
#  'from',
#  'time',
#  'to',
#  'time',
#  'the',
#  'great',
#  'dead',
#  'phil',
#  'communicate',
#  'to',
#  'spirit',
#  'devoured',
#  'with',
#  'skepticism',
#  'and',
#  'down',
#  'a',
#  'religious',
#  'fervor',
#  'providence',
#  'knows',
#  'what',
#  'it',
#  'does',
#  'when',
#  'it',
#  'puts',
#  'people',
#  'face',
#  'to',
#  'face',
#  'with',
#  'the',
#  'soup',
#  'read',
#  'mysteries',
#  'how',
#  'many',
#  'gives',
#  'them']

# %%
unique = []
for word in sentence_list:
  if word not in unique:
      unique.append(word)

#sort
unique.sort()

#print
print(unique)
# Out:
# ['a', 'about', 'above', 'abyss', 'accept', 'accomplished', 'across', 'act', 'adams', 'after', 'again', 'ago', 'all', 'among', 'amount', 'an', 'and', 'another', 'answerable', 'appendix', 'are', 'art', 'as', 'at', 'august', 'author', 'back', 'balance', 'balzac', 'be', 'beads', 'because', 'belzak', 'best', 'beyond', 'bianca', 'black', 'body', 'book', 'bookcase', 'books', 'bounce', 'bowser', 'brain', 'but', 'by', 'called', 'came', 'can', 'carnegie', 'catastrophes', 'catch', 'century', 'civilization', 'clearly', 'clothes', 'clouds', 'come', 'comedy', 'coming', 'commonplace', 'communicate', 'comprehend', 'congress', 'conquerors', 'consented', 'constituted', 'contemporary', 'contention', 'could', 'country', 'd', 'dale', 'day', 'days', 'de', 'dead', 'death', 'delivered', 'destiny', 'development', 'devoured', 'disappears', 'dissected', 'distant', 'distressing', 'does', 'down', 'dying', 'each', 'embrace', 'enters', 'entitled', 'envy', 'epochal', 'escapes', 'esoteric', 'ever', 'face', 'fatigued', 'feeling', 'fervor', 'few', 'fictions', 'filled', 'finca', 'first', 'fixed', 'for', 'formalin', 'formidable', 'forms', 'france', 'free', 'from', 'full', 'funeral', 'future', 'generation', 'genius', 'gentleman', 'gives', 'glory', 'goal', 'goes', 'going', 'good', 'grace', 'grandly', 'granite', 'great', 'greatest', 'griffin', 'had', 'hair', 'has', 'hatred', 'have', 'having', 'he', 'heads', 'headset', 'heights', 'her', 'here', 'highest', 'him', 'himself', 'his', 'history', 'hold', 'homage', 'honore', 'hope', 'hot', 'how', 'hugo', 'humanity', 'hundreds', 'i', 'ideal', 'illusion', 'imagination', 'immense', 'in', 'industrious', 'information', 'insects', 'intellect', 'intelligence', 'into', 'is', 'it', 'joseph', 'know', 'knows', 'lavishes', 'law', 'layers', 'leave', 'left', 'let', 'librivox', 'life', 'like', 'lived', 'living', 'lost', 'luminous', 'm', 'make', 'man', 'many', 'marching', 'material', 'maybe', 'melancholy', 'men', 'mingled', 'misanthropy', 'mixed', 'modern', 'molly', 'months', 'monument', 'more', 'most', 'mother', 'mourning', 'moved', 'moving', 'mysteries', 'name', 'nation', 'nature', 'necessary', 'never', 'nineteenth', 'not', 'now', 'obelisk', 'observation', 'of', 'off', 'office', 'often', 'ola', 'old', 'on', 'once', 'one', 'only', 'or', 'org', 'our', 'out', 'own', 'paris', 'passion', 'paul', 'pays', 'peace', 'pedestal', 'people', 'perhaps', 'phil', 'philosopher', 'piled', 'place', 'play', 'plaza', 'please', 'poet', 'polian', 'powerful', 'practice', 'present', 'presents', 'privilege', 'produced', 'profound', 'providence', 'provoked', 'public', 'put', 'puts', 'queef', 'race', 'ransacked', 're', 'read', 'real', 'realizes', 'recording', 'redeem', 'reflow', 'religious', 'renowned', 'rental', 'resignation', 'revolutionist', 'revolutions', 'rice', 'right', 'rihanna', 'robustly', 'russo', 's', 'same', 'sasha', 'section', 'see', 'seen', 'sees', 'severe', 'shells', 'shine', 'short', 'skepticism', 'smiling', 'so', 'society', 'solid', 'somber', 'something', 'sounded', 'soup', 'sovereign', 'speaking', 'speeches', 'spirit', 'splenda', 'splendid', 'stars', 'statue', 'straight', 'strange', 'strife', 'strong', 'studies', 'study', 'stupefied', 'styles', 'successes', 'sucked', 'suetonius', 'surpasses', 'swiftly', 'sword', 'tacitus', 'takes', 'talent', 'teapot', 'tell', 'tempted', 'terrible', 'th', 'that', 'the', 'their', 'them', 'there', 'these', 'they', 'think', 'this', 'those', 'through', 'time', 'times', 'to', 'today', 'tonight', 'trace', 'tragic', 'trails', 'trivial', 'truth', 'tube', 'unknown', 'up', 'us', 'vanished', 'vice', 'victor', 'vigorous', 'volunteer', 'voyage', 'w', 'walk', 'wanna', 'was', 'we', 'were', 'what', 'whatever', 'when', 'where', 'whether', 'which', 'who', 'whole', 'whom', 'will', 'wine', 'wish', 'wished', 'with', 'within', 'words', 'work', 'worker', 'would', 'wrecked', 'you', 'ziff']

# %%
number_of_words = dict.fromkeys(unique, 0)
for word in sentence_list:
  number_of_words[word] +=1
number_of_words
# Out:
# {'a': 15,
#  'about': 1,
#  'above': 1,
#  'abyss': 1,
#  'accept': 2,
#  'accomplished': 1,
#  'across': 1,
#  'act': 1,
#  'adams': 1,
#  'after': 1,
#  'again': 1,
#  'ago': 1,
#  'all': 5,
#  'among': 5,
#  'amount': 1,
#  'an': 1,
#  'and': 25,
#  'another': 1,
#  'answerable': 1,
#  'appendix': 1,
#  'are': 3,
#  'art': 1,
#  'as': 3,
#  'at': 4,
#  'august': 1,
#  'author': 1,
#  'back': 2,
#  'balance': 2,
#  'balzac': 1,
#  'be': 2,
#  'beads': 1,
#  'because': 1,
#  'belzak': 1,
#  'best': 1,
#  'beyond': 1,
#  'bianca': 1,
#  'black': 1,
#  'body': 2,
#  'book': 4,
#  'bookcase': 1,
#  'books': 1,
#  'bounce': 2,
#  'bowser': 1,
#  'brain': 1,
#  'but': 1,
#  'by': 6,
#  'called': 1,
#  'came': 2,
#  'can': 1,
#  'carnegie': 1,
#  'catastrophes': 1,
#  'catch': 1,
#  'century': 2,
#  'civilization': 2,
#  'clearly': 1,
#  'clothes': 1,
#  'clouds': 1,
#  'come': 2,
#  'comedy': 1,
#  'coming': 1,
#  'commonplace': 1,
#  'communicate': 1,
#  'comprehend': 1,
#  'congress': 1,
#  'conquerors': 1,
#  'consented': 1,
#  'constituted': 1,
#  'contemporary': 1,
#  'contention': 1,
#  'could': 1,
#  'country': 3,
#  'd': 1,
#  'dale': 1,
#  'day': 2,
#  'days': 1,
#  'de': 1,
#  'dead': 1,
#  'death': 2,
#  'delivered': 1,
#  'destiny': 1,
#  'development': 1,
#  'devoured': 1,
#  'disappears': 1,
#  'dissected': 1,
#  'distant': 1,
#  'distressing': 1,
#  'does': 1,
#  'down': 2,
#  'dying': 1,
#  'each': 1,
#  'embrace': 1,
#  'enters': 1,
#  'entitled': 1,
#  'envy': 1,
#  'epochal': 1,
#  'escapes': 1,
#  'esoteric': 1,
#  'ever': 1,
#  'face': 4,
#  'fatigued': 1,
#  'feeling': 1,
#  'fervor': 1,
#  'few': 1,
#  'fictions': 1,
#  'filled': 1,
#  'finca': 1,
#  'first': 1,
#  'fixed': 1,
#  'for': 4,
#  'formalin': 1,
#  'formidable': 1,
#  'forms': 1,
#  'france': 1,
#  'free': 1,
#  'from': 10,
#  'full': 1,
#  'funeral': 1,
#  'future': 2,
#  'generation': 1,
#  'genius': 2,
#  'gentleman': 2,
#  'gives': 2,
#  'glory': 1,
#  'goal': 1,
#  'goes': 2,
#  'going': 1,
#  'good': 1,
#  'grace': 1,
#  'grandly': 1,
#  'granite': 1,
#  'great': 3,
#  'greatest': 1,
#  'griffin': 1,
#  'had': 1,
#  'hair': 1,
#  'has': 4,
#  'hatred': 1,
#  'have': 3,
#  'having': 1,
#  'he': 17,
#  'heads': 3,
#  'headset': 1,
#  'heights': 1,
#  'her': 1,
#  'here': 1,
#  'highest': 1,
#  'him': 1,
#  'himself': 3,
#  'his': 10,
#  'history': 1,
#  'hold': 1,
#  'homage': 1,
#  'honore': 1,
#  'hope': 1,
#  'hot': 1,
#  'how': 2,
#  'hugo': 1,
#  'humanity': 1,
#  'hundreds': 1,
#  'i': 3,
#  'ideal': 1,
#  'illusion': 1,
#  'imagination': 1,
#  'immense': 1,
#  'in': 11,
#  'industrious': 1,
#  'information': 1,
#  'insects': 1,
#  'intellect': 1,
#  'intelligence': 1,
#  'into': 2,
#  'is': 13,
#  'it': 7,
#  'joseph': 1,
#  'know': 1,
#  'knows': 1,
#  'lavishes': 1,
#  'law': 1,
#  'layers': 1,
#  'leave': 1,
#  'left': 1,
#  'let': 2,
#  'librivox': 2,
#  'life': 2,
#  'like': 1,
#  'lived': 1,
#  'living': 1,
#  'lost': 2,
#  'luminous': 2,
#  'm': 1,
#  'make': 1,
#  'man': 4,
#  'many': 1,
#  'marching': 1,
#  'material': 1,
#  'maybe': 1,
#  'melancholy': 1,
#  'men': 2,
#  'mingled': 1,
#  'misanthropy': 1,
#  'mixed': 1,
#  'modern': 1,
#  'molly': 1,
#  'months': 1,
#  'monument': 1,
#  'more': 3,
#  'most': 1,
#  'mother': 1,
#  'mourning': 1,
#  'moved': 1,
#  'moving': 1,
#  'mysteries': 1,
#  'name': 1,
#  'nation': 1,
#  'nature': 1,
#  'necessary': 1,
#  'never': 1,
#  'nineteenth': 1,
#  'not': 6,
#  'now': 1,
#  'obelisk': 1,
#  'observation': 1,
#  'of': 31,
#  'off': 2,
#  'office': 1,
#  'often': 1,
#  'ola': 1,
#  'old': 2,
#  'on': 5,
#  'once': 1,
#  'one': 10,
#  'only': 3,
#  'or': 4,
#  'org': 1,
#  'our': 1,
#  'out': 2,
#  'own': 1,
#  'paris': 1,
#  'passion': 1,
#  'paul': 1,
#  'pays': 1,
#  'peace': 1,
#  'pedestal': 1,
#  'people': 2,
#  'perhaps': 2,
#  'phil': 1,
#  'philosopher': 1,
#  'piled': 1,
#  'place': 1,
#  'play': 1,
#  'plaza': 1,
#  'please': 1,
#  'poet': 2,
#  'polian': 1,
#  'powerful': 2,
#  'practice': 1,
#  'present': 1,
#  'presents': 1,
#  'privilege': 1,
#  'produced': 1,
#  'profound': 1,
#  'providence': 2,
#  'provoked': 1,
#  'public': 4,
#  'put': 1,
#  'puts': 1,
#  'queef': 1,
#  'race': 1,
#  'ransacked': 1,
#  're': 1,
#  'read': 1,
#  'real': 1,
#  'realizes': 1,
#  'recording': 3,
#  'redeem': 1,
#  'reflow': 1,
#  'religious': 1,
#  'renowned': 1,
#  'rental': 1,
#  'resignation': 1,
#  'revolutionist': 1,
#  'revolutions': 1,
#  'rice': 2,
#  'right': 1,
#  'rihanna': 1,
#  'robustly': 1,
#  'russo': 1,
#  's': 4,
#  'same': 1,
#  'sasha': 1,
#  'section': 2,
#  'see': 2,
#  'seen': 1,
#  'sees': 1,
#  'severe': 2,
#  'shells': 1,
#  'shine': 2,
#  'short': 1,
#  'skepticism': 1,
#  'smiling': 1,
#  'so': 1,
#  'society': 1,
#  'solid': 1,
#  'somber': 1,
#  'something': 1,
#  'sounded': 1,
#  'soup': 1,
#  'sovereign': 1,
#  'speaking': 2,
#  'speeches': 1,
#  'spirit': 1,
#  'splenda': 1,
#  'splendid': 1,
#  'stars': 1,
#  'statue': 1,
#  'straight': 1,
#  'strange': 1,
#  'strife': 1,
#  'strong': 1,
#  'studies': 1,
#  'study': 1,
#  'stupefied': 1,
#  'styles': 1,
#  'successes': 1,
#  'sucked': 1,
#  'suetonius': 1,
#  'surpasses': 1,
#  'swiftly': 1,
#  'sword': 1,
#  'tacitus': 1,
#  'takes': 1,
#  'talent': 1,
#  'teapot': 1,
#  'tell': 1,
#  'tempted': 1,
#  'terrible': 1,
#  'th': 3,
#  'that': 6,
#  'the': 52,
#  'their': 1,
#  'them': 1,
#  'there': 1,
#  'these': 2,
#  'they': 1,
#  'think': 1,
#  'this': 11,
#  'those': 4,
#  'through': 1,
#  'time': 3,
#  'times': 2,
#  'to': 18,
#  'today': 2,
#  'tonight': 1,
#  'trace': 1,
#  'tragic': 1,
#  'trails': 1,
#  'trivial': 1,
#  'truth': 1,
#  'tube': 2,
#  'unknown': 1,
#  'up': 1,
#  'us': 5,
#  'vanished': 1,
#  'vice': 1,
#  'victor': 1,
#  'vigorous': 1,
#  'volunteer': 1,
#  'voyage': 1,
#  'w': 1,
#  'walk': 1,
#  'wanna': 1,
#  'was': 4,
#  'we': 1,
#  'were': 1,
#  'what': 3,
#  'whatever': 2,
#  'when': 2,
#  'where': 1,
#  'whether': 2,
#  'which': 11,
#  'who': 4,
#  'whole': 1,
#  'whom': 1,
#  'will': 3,
#  'wine': 1,
#  'wish': 2,
#  'wished': 1,
#  'with': 7,
#  'within': 1,
#  'words': 1,
#  'work': 2,
#  'worker': 1,
#  'would': 1,
#  'wrecked': 1,
#  'you': 3,
#  'ziff': 1}

# %%
import pandas as pd
df = pd.DataFrame(number_of_words, index=[0])
df
# Out:
#     a  about  above  abyss  accept  accomplished  across  act  adams  after  \
# 0  15      1      1      1       2             1       1    1      1      1
#
#    ...  wished  with  within  words  work  worker  would  wrecked  you  ziff
# 0  ...       1     7       1      1     2       1      1        1    3     1
#
# [1 rows x 396 columns]

# %%
#calculating TF
def TF(word_dict, list_of_words):
  tf_dict = {}
  corpusCount = len(list_of_words)
  for word, count in word_dict.items():
    tf_dict[word] = count / float(corpusCount)
  return tf_dict

# %%
tf = TF(number_of_words, sentence_list)
tf
# Out:
# {'a': 0.019305019305019305,
#  'about': 0.001287001287001287,
#  'above': 0.001287001287001287,
#  'abyss': 0.001287001287001287,
#  'accept': 0.002574002574002574,
#  'accomplished': 0.001287001287001287,
#  'across': 0.001287001287001287,
#  'act': 0.001287001287001287,
#  'adams': 0.001287001287001287,
#  'after': 0.001287001287001287,
#  'again': 0.001287001287001287,
#  'ago': 0.001287001287001287,
#  'all': 0.006435006435006435,
#  'among': 0.006435006435006435,
#  'amount': 0.001287001287001287,
#  'an': 0.001287001287001287,
#  'and': 0.032175032175032175,
#  'another': 0.001287001287001287,
#  'answerable': 0.001287001287001287,
#  'appendix': 0.001287001287001287,
#  'are': 0.003861003861003861,
#  'art': 0.001287001287001287,
#  'as': 0.003861003861003861,
#  'at': 0.005148005148005148,
#  'august': 0.001287001287001287,
#  'author': 0.001287001287001287,
#  'back': 0.002574002574002574,
#  'balance': 0.002574002574002574,
#  'balzac': 0.001287001287001287,
#  'be': 0.002574002574002574,
#  'beads': 0.001287001287001287,
#  'because': 0.001287001287001287,
#  'belzak': 0.001287001287001287,
#  'best': 0.001287001287001287,
#  'beyond': 0.001287001287001287,
#  'bianca': 0.001287001287001287,
#  'black': 0.001287001287001287,
#  'body': 0.002574002574002574,
#  'book': 0.005148005148005148,
#  'bookcase': 0.001287001287001287,
#  'books': 0.001287001287001287,
#  'bounce': 0.002574002574002574,
#  'bowser': 0.001287001287001287,
#  'brain': 0.001287001287001287,
#  'but': 0.001287001287001287,
#  'by': 0.007722007722007722,
#  'called': 0.001287001287001287,
#  'came': 0.002574002574002574,
#  'can': 0.001287001287001287,
#  'carnegie': 0.001287001287001287,
#  'catastrophes': 0.001287001287001287,
#  'catch': 0.001287001287001287,
#  'century': 0.002574002574002574,
#  'civilization': 0.002574002574002574,
#  'clearly': 0.001287001287001287,
#  'clothes': 0.001287001287001287,
#  'clouds': 0.001287001287001287,
#  'come': 0.002574002574002574,
#  'comedy': 0.001287001287001287,
#  'coming': 0.001287001287001287,
#  'commonplace': 0.001287001287001287,
#  'communicate': 0.001287001287001287,
#  'comprehend': 0.001287001287001287,
#  'congress': 0.001287001287001287,
#  'conquerors': 0.001287001287001287,
#  'consented': 0.001287001287001287,
#  'constituted': 0.001287001287001287,
#  'contemporary': 0.001287001287001287,
#  'contention': 0.001287001287001287,
#  'could': 0.001287001287001287,
#  'country': 0.003861003861003861,
#  'd': 0.001287001287001287,
#  'dale': 0.001287001287001287,
#  'day': 0.002574002574002574,
#  'days': 0.001287001287001287,
#  'de': 0.001287001287001287,
#  'dead': 0.001287001287001287,
#  'death': 0.002574002574002574,
#  'delivered': 0.001287001287001287,
#  'destiny': 0.001287001287001287,
#  'development': 0.001287001287001287,
#  'devoured': 0.001287001287001287,
#  'disappears': 0.001287001287001287,
#  'dissected': 0.001287001287001287,
#  'tragic': 0.001287001287001287,
#  'trails': 0.001287001287001287,
#  'trivial': 0.001287001287001287,
#  'truth': 0.001287001287001287,
#  'tube': 0.002574002574002574,
#  'unknown': 0.001287001287001287,
#  'up': 0.001287001287001287,
#  'us': 0.006435006435006435,
#  'vanished': 0.001287001287001287,
#  'vice': 0.001287001287001287,
#  'victor': 0.001287001287001287,
#  'vigorous': 0.001287001287001287,
#  'volunteer': 0.001287001287001287,
#  'voyage': 0.001287001287001287,
#  'w': 0.001287001287001287,
#  'walk': 0.001287001287001287,
#  'wanna': 0.001287001287001287,
#  'was': 0.005148005148005148,
#  'we': 0.001287001287001287,
#  'were': 0.001287001287001287,
#  'what': 0.003861003861003861,
#  'whatever': 0.002574002574002574,
#  'when': 0.002574002574002574,
#  'where': 0.001287001287001287,
#  'whether': 0.002574002574002574,
#  'which': 0.014157014157014158,
#  'who': 0.005148005148005148,
#  'whole': 0.001287001287001287,
#  'whom': 0.001287001287001287,
#  'will': 0.003861003861003861,
#  'wine': 0.001287001287001287,
#  'wish': 0.002574002574002574,
#  'wished': 0.001287001287001287,
#  'with': 0.009009009009009009,
#  'within': 0.001287001287001287,
#  'words': 0.001287001287001287,
#  'work': 0.002574002574002574,
#  'worker': 0.001287001287001287,
#  'would': 0.001287001287001287,
#  'wrecked': 0.001287001287001287,
#  'you': 0.003861003861003861,
#  'ziff': 0.001287001287001287}

# %%
df1 = pd.DataFrame(tf, index=[0])
df1
# Out:
#           a     about     above     abyss    accept  accomplished    across  \
# 0  0.019305  0.001287  0.001287  0.001287  0.002574      0.001287  0.001287
#
#         act     adams     after  ...    wished      with    within     words  \
# 0  0.001287  0.001287  0.001287  ...  0.001287  0.009009  0.001287  0.001287
#
#        work    worker     would   wrecked       you      ziff
# 0  0.002574  0.001287  0.001287  0.001287  0.003861  0.001287
#
# [1 rows x 396 columns]

# %%
stopwords = nltk.corpus.stopwords.words('english')

word_frequencies = {}
for word in nltk.word_tokenize(formatted_article_text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1
print(word_frequencies)
# Out:
# {'Section': 2, 'art': 1, 'public': 4, 'speaking': 2, 'librivox': 2, 'recording': 2, 'Only': 2, 'provoked': 1, 'tonight': 1, 'More': 2, 'information': 1, 'volunteer': 1, 'Please': 1, 'present': 1, 'org': 1, 'Recording': 1, 'paul': 1, 'adams': 1, 'The': 7, 'office': 1, 'dale': 1, 'carnegie': 1, 'joseph': 1, 'bookcase': 1, 'wine': 1, 'Appendix': 1, 'Speeches': 1, 'study': 1, 'practice': 1, 'Victor': 1, 'hugo': 1, 'honore': 1, 'de': 1, 'balzac': 1, 'Delivered': 1, 'funeral': 1, 'balance': 1, 'august': 1, 'th': 3, 'Gentleman': 2, 'man': 4, 'goes': 2, 'tube': 2, 'one': 10, 'queef': 1, 'pays': 1, 'homage': 1, 'In': 2, 'day': 2, 'fictions': 1, 'vanished': 1, 'Bianca': 1, 'fixed': 1, 'heads': 3, 'right': 1, '
'russo': 1, 'accomplished': 1, 'us': 5, 'left': 1, 'walk': 1, 'lost': 2, 'solid': 1, 'monument': 1, 'robustly': 1, 'piled': 1, 'layers': 1, 'granite': 1, 'heights': 1, 'hair': 1, 'renowned': 1, 'shells': 1, 'shine': 2, 'splenda': 1, 'Great': 1, 'men': 2, 'make': 1, 'pedestal': 1, 'answerable': 1, 'statue': 1, 'His': 2, 'stupefied': 1, 'paris': 1, 'months': 1, 'ago': 1, 'come': 2, 'back': 2, 'france': 1, 'feeling': 1, 'dying': 1, 'would': 1, 'embrace': 1, 'mother': 1, 'distant': 1, 'voyage': 1, 'life': 2, 'short': 1, 'full': 1, 'filled': 1, 'beads': 1, 'days': 1, 'worker': 1, 'never': 1, 'fatigued': 1, 'philosopher': 1, 'finca': 1, 'lived': 1, 'strife': 1, 'clothes': 1, 'great': 2, 'peace': 1, 'escapes': 1, 'contention': 1, 'hatred': 1, 'On': 1, 'enters': 1, 'glory': 1, 'They': 1, 'beyond': 1, 'clouds': 1, 'star ...

# %%
#calculating IDF
def IDF(documents):
  import math
  N = len(documents)
  idf_dict = dict.fromkeys(documents[0].keys(), 0)
  for document in documents:
    for word, val in document.items():
      if val>0:
        idf_dict[word] += 1
  for word, val in idf_dict.items():
    idf_dict[word] = math.log(N / float(val)+1)
  return idf_dict

# %%
Idf = IDF([number_of_words])
Idf
# Out:
# {'a': 0.6931471805599453,
#  'about': 0.6931471805599453,
#  'above': 0.6931471805599453,
#  'abyss': 0.6931471805599453,
#  'accept': 0.6931471805599453,
#  'accomplished': 0.6931471805599453,
#  'across': 0.6931471805599453,
#  'act': 0.6931471805599453,
#  'adams': 0.6931471805599453,
#  'after': 0.6931471805599453,
#  'again': 0.6931471805599453,
#  'ago': 0.6931471805599453,
#  'all': 0.6931471805599453,
#  'among': 0.6931471805599453,
#  'amount': 0.6931471805599453,
#  'an': 0.6931471805599453,
#  'and': 0.6931471805599453,
#  'another': 0.6931471805599453,
#  'answerable': 0.6931471805599453,
#  'appendix': 0.6931471805599453,
#  'are': 0.6931471805599453,
#  'art': 0.6931471805599453,
#  'as': 0.6931471805599453,
#  'at': 0.6931471805599453,
#  'august': 0.6931471805599453,
#  'author': 0.6931471805599453,
#  'back': 0.6931471805599453,
#  'balance': 0.6931471805599453,
#  'balzac': 0.6931471805599453,
#  'be': 0.6931471805599453,
#  'beads': 0.6931471805599453,
#  'because': 0.6931471805599453,
#  'belzak': 0.6931471805599453,
#  'best': 0.6931471805599453,
#  'beyond': 0.6931471805599453,
#  'bianca': 0.6931471805599453,
#  'black': 0.6931471805599453,
#  'body': 0.6931471805599453,
#  'book': 0.6931471805599453,
#  'bookcase': 0.6931471805599453,
#  'books': 0.6931471805599453,
#  'bounce': 0.6931471805599453,
#  'bowser': 0.6931471805599453,
#  'brain': 0.6931471805599453,
#  'but': 0.6931471805599453,
#  'by': 0.6931471805599453,
#  'called': 0.6931471805599453,
#  'came': 0.6931471805599453,
#  'can': 0.6931471805599453,
#  'carnegie': 0.6931471805599453,
#  'catastrophes': 0.6931471805599453,
#  'catch': 0.6931471805599453,
#  'century': 0.6931471805599453,
#  'civilization': 0.6931471805599453,
#  'clearly': 0.6931471805599453,
#  'clothes': 0.6931471805599453,
#  'clouds': 0.6931471805599453,
#  'come': 0.6931471805599453,
#  'comedy': 0.6931471805599453,
#  'coming': 0.6931471805599453,
#  'commonplace': 0.6931471805599453,
#  'communicate': 0.6931471805599453,
#  'comprehend': 0.6931471805599453,
#  'congress': 0.6931471805599453,
#  'conquerors': 0.6931471805599453,
#  'consented': 0.6931471805599453,
#  'constituted': 0.6931471805599453,
#  'contemporary': 0.6931471805599453,
#  'contention': 0.6931471805599453,
#  'could': 0.6931471805599453,
#  'country': 0.6931471805599453,
#  'd': 0.6931471805599453,
#  'dale': 0.6931471805599453,
#  'day': 0.6931471805599453,
#  'days': 0.6931471805599453,
#  'de': 0.6931471805599453,
#  'dead': 0.6931471805599453,
#  'death': 0.6931471805599453,
#  'delivered': 0.6931471805599453,
#  'destiny': 0.6931471805599453,
#  'development': 0.6931471805599453,
#  'devoured': 0.6931471805599453,
#  'disappears': 0.6931471805599453,
#  'dissected': 0.6931471805599453,
#  'distant': 0.6931471805599453,
#  'distressing': 0.6931471805599453,
#  'does': 0.6931471805599453,
#  'down': 0.6931471805599453,
#  'dying': 0.6931471805599453,
#  'each': 0.6931471805599453,
#  'embrace': 0.6931471805599453,
#  'enters': 0.6931471805599453,
#  'entitled': 0.6931471805599453,
#  'envy': 0.6931471805599453,
#  'epochal': 0.6931471805599453,
#  'escapes': 0.6931471805599453,
#  'esoteric': 0.6931471805599453,
#  'ever': 0.6931471805599453,
#  'face': 0.6931471805599453,
#  'fatigued': 0.6931471805599453,
#  'feeling': 0.6931471805599453,
#  'fervor': 0.6931471805599453,
#  'few': 0.6931471805599453,
#  'fictions': 0.6931471805599453,
#  'filled': 0.6931471805599453,
#  'finca': 0.6931471805599453,
#  'first': 0.6931471805599453,
#  'fixed': 0.6931471805599453,
#  'for': 0.6931471805599453,
#  'formalin': 0.6931471805599453,
#  'formidable': 0.6931471805599453,
#  'forms': 0.6931471805599453,
#  'france': 0.6931471805599453,
#  'free': 0.6931471805599453,
#  'from': 0.6931471805599453,
#  'full': 0.6931471805599453,
#  'funeral': 0.6931471805599453,
#  'future': 0.6931471805599453,
#  'generation': 0.6931471805599453,
#  'genius': 0.6931471805599453,
#  'gentleman': 0.6931471805599453,
#  'gives': 0.6931471805599453,
#  'glory': 0.6931471805599453,
#  'goal': 0.6931471805599453,
#  'goes': 0.6931471805599453,
#  'going': 0.6931471805599453,
#  'good': 0.6931471805599453,
#  'grace': 0.6931471805599453,
#  'grandly': 0.6931471805599453,
#  'granite': 0.6931471805599453,
#  'great': 0.6931471805599453,
#  'greatest': 0.6931471805599453,
#  'griffin': 0.6931471805599453,
#  'had': 0.6931471805599453,
#  'hair': 0.6931471805599453,
#  'has': 0.6931471805599453,
#  'hatred': 0.6931471805599453,
#  'have': 0.6931471805599453,
#  'having': 0.6931471805599453,
#  'he': 0.6931471805599453,
#  'heads': 0.6931471805599453,
#  'headset': 0.6931471805599453,
#  'heights': 0.6931471805599453,
#  'her': 0.6931471805599453,
#  'here': 0.6931471805599453,
#  'highest': 0.6931471805599453,
#  'him': 0.6931471805599453,
#  'himself': 0.6931471805599453,
#  'his': 0.6931471805599453,
#  'history': 0.6931471805599453,
#  'hold': 0.6931471805599453,
#  'homage': 0.6931471805599453,
#  'honore': 0.6931471805599453,
#  'hope': 0.6931471805599453,
#  'hot': 0.6931471805599453,
#  'how': 0.6931471805599453,
#  'hugo': 0.6931471805599453,
#  'humanity': 0.6931471805599453,
#  'hundreds': 0.6931471805599453,
#  'i': 0.6931471805599453,
#  'ideal': 0.6931471805599453,
#  'illusion': 0.6931471805599453,
#  'imagination': 0.6931471805599453,
#  'immense': 0.6931471805599453,
#  'in': 0.6931471805599453,
#  'industrious': 0.6931471805599453,
#  'information': 0.6931471805599453,
#  'insects': 0.6931471805599453,
#  'intellect': 0.6931471805599453,
#  'intelligence': 0.6931471805599453,
#  'into': 0.6931471805599453,
#  'is': 0.6931471805599453,
#  'it': 0.6931471805599453,
#  'joseph': 0.6931471805599453,
#  'know': 0.6931471805599453,
#  'knows': 0.6931471805599453,
#  'lavishes': 0.6931471805599453,
#  'law': 0.6931471805599453,
#  'layers': 0.6931471805599453,
#  'leave': 0.6931471805599453,
#  'left': 0.6931471805599453,
#  'let': 0.6931471805599453,
#  'librivox': 0.6931471805599453,
#  'life': 0.6931471805599453,
#  'like': 0.6931471805599453,
#  'lived': 0.6931471805599453,
#  'living': 0.6931471805599453,
#  'lost': 0.6931471805599453,
#  'luminous': 0.6931471805599453,
#  'm': 0.6931471805599453,
#  'make': 0.6931471805599453,
#  'man': 0.6931471805599453,
#  'many': 0.6931471805599453,
#  'marching': 0.6931471805599453,
#  'material': 0.6931471805599453,
#  'maybe': 0.6931471805599453,
#  'melancholy': 0.6931471805599453,
#  'men': 0.6931471805599453,
#  'mingled': 0.6931471805599453,
#  'misanthropy': 0.6931471805599453,
#  'mixed': 0.6931471805599453,
#  'modern': 0.6931471805599453,
#  'molly': 0.6931471805599453,
#  'months': 0.6931471805599453,
#  'monument': 0.6931471805599453,
#  'more': 0.6931471805599453,
#  'most': 0.6931471805599453,
#  'mother': 0.6931471805599453,
#  'mourning': 0.6931471805599453,
#  'moved': 0.6931471805599453,
#  'moving': 0.6931471805599453,
#  'mysteries': 0.6931471805599453,
#  'name': 0.6931471805599453,
#  'nation': 0.6931471805599453,
#  'nature': 0.6931471805599453,
#  'necessary': 0.6931471805599453,
#  'never': 0.6931471805599453,
#  'nineteenth': 0.6931471805599453,
#  'not': 0.6931471805599453,
#  'now': 0.6931471805599453,
#  'obelisk': 0.6931471805599453,
#  'observation': 0.6931471805599453,
#  'of': 0.6931471805599453,
#  'off': 0.6931471805599453,
#  'office': 0.6931471805599453,
#  'often': 0.6931471805599453,
#  'ola': 0.6931471805599453,
#  'old': 0.6931471805599453,
#  'on': 0.6931471805599453,
#  'once': 0.6931471805599453,
#  'one': 0.6931471805599453,
#  'only': 0.6931471805599453,
#  'or': 0.6931471805599453,
#  'org': 0.6931471805599453,
#  'our': 0.6931471805599453,
#  'out': 0.6931471805599453,
#  'own': 0.6931471805599453,
#  'paris': 0.6931471805599453,
#  'passion': 0.6931471805599453,
#  'paul': 0.6931471805599453,
#  'pays': 0.6931471805599453,
#  'peace': 0.6931471805599453,
#  'pedestal': 0.6931471805599453,
#  'people': 0.6931471805599453,
#  'perhaps': 0.6931471805599453,
#  'phil': 0.6931471805599453,
#  'philosopher': 0.6931471805599453,
#  'piled': 0.6931471805599453,
#  'place': 0.6931471805599453,
#  'play': 0.6931471805599453,
#  'plaza': 0.6931471805599453,
#  'please': 0.6931471805599453,
#  'poet': 0.6931471805599453,
#  'polian': 0.6931471805599453,
#  'powerful': 0.6931471805599453,
#  'practice': 0.6931471805599453,
#  'present': 0.6931471805599453,
#  'presents': 0.6931471805599453,
#  'privilege': 0.6931471805599453,
#  'produced': 0.6931471805599453,
#  'profound': 0.6931471805599453,
#  'providence': 0.6931471805599453,
#  'provoked': 0.6931471805599453,
#  'public': 0.6931471805599453,
#  'put': 0.6931471805599453,
#  'puts': 0.6931471805599453,
#  'queef': 0.6931471805599453,
#  'race': 0.6931471805599453,
#  'ransacked': 0.6931471805599453,
#  're': 0.6931471805599453,
#  'read': 0.6931471805599453,
#  'real': 0.6931471805599453,
#  'realizes': 0.6931471805599453,
#  'recording': 0.6931471805599453,
#  'redeem': 0.6931471805599453,
#  'reflow': 0.6931471805599453,
#  'religious': 0.6931471805599453,
#  'renowned': 0.6931471805599453,
#  'rental': 0.6931471805599453,
#  'resignation': 0.6931471805599453,
#  'revolutionist': 0.6931471805599453,
#  'revolutions': 0.6931471805599453,
#  'rice': 0.6931471805599453,
#  'right': 0.6931471805599453,
#  'rihanna': 0.6931471805599453,
#  'robustly': 0.6931471805599453,
#  'russo': 0.6931471805599453,
#  's': 0.6931471805599453,
#  'same': 0.6931471805599453,
#  'sasha': 0.6931471805599453,
#  'section': 0.6931471805599453,
#  'see': 0.6931471805599453,
#  'seen': 0.6931471805599453,
#  'sees': 0.6931471805599453,
#  'severe': 0.6931471805599453,
#  'shells': 0.6931471805599453,
#  'shine': 0.6931471805599453,
#  'short': 0.6931471805599453,
#  'skepticism': 0.6931471805599453,
#  'smiling': 0.6931471805599453,
#  'so': 0.6931471805599453,
#  'society': 0.6931471805599453,
#  'solid': 0.6931471805599453,
#  'somber': 0.6931471805599453,
#  'something': 0.6931471805599453,
#  'sounded': 0.6931471805599453,
#  'soup': 0.6931471805599453,
#  'sovereign': 0.6931471805599453,
#  'speaking': 0.6931471805599453,
#  'speeches': 0.6931471805599453,
#  'spirit': 0.6931471805599453,
#  'splenda': 0.6931471805599453,
#  'splendid': 0.6931471805599453,
#  'stars': 0.6931471805599453,
#  'statue': 0.6931471805599453,
#  'straight': 0.6931471805599453,
#  'strange': 0.6931471805599453,
#  'strife': 0.6931471805599453,
#  'strong': 0.6931471805599453,
#  'studies': 0.6931471805599453,
#  'study': 0.6931471805599453,
#  'stupefied': 0.6931471805599453,
#  'styles': 0.6931471805599453,
#  'successes': 0.6931471805599453,
#  'sucked': 0.6931471805599453,
#  'suetonius': 0.6931471805599453,
#  'surpasses': 0.6931471805599453,
#  'swiftly': 0.6931471805599453,
#  'sword': 0.6931471805599453,
#  'tacitus': 0.6931471805599453,
#  'takes': 0.6931471805599453,
#  'talent': 0.6931471805599453,
#  'teapot': 0.6931471805599453,
#  'tell': 0.6931471805599453,
#  'tempted': 0.6931471805599453,
#  'terrible': 0.6931471805599453,
#  'th': 0.6931471805599453,
#  'that': 0.6931471805599453,
#  'the': 0.6931471805599453,
#  'their': 0.6931471805599453,
#  'them': 0.6931471805599453,
#  'there': 0.6931471805599453,
#  'these': 0.6931471805599453,
#  'they': 0.6931471805599453,
#  'think': 0.6931471805599453,
#  'this': 0.6931471805599453,
#  'those': 0.6931471805599453,
#  'through': 0.6931471805599453,
#  'time': 0.6931471805599453,
#  'times': 0.6931471805599453,
#  'to': 0.6931471805599453,
#  'today': 0.6931471805599453,
#  'tonight': 0.6931471805599453,
#  'trace': 0.6931471805599453,
#  'tragic': 0.6931471805599453,
#  'trails': 0.6931471805599453,
#  'trivial': 0.6931471805599453,
#  'truth': 0.6931471805599453,
#  'tube': 0.6931471805599453,
#  'unknown': 0.6931471805599453,
#  'up': 0.6931471805599453,
#  'us': 0.6931471805599453,
#  'vanished': 0.6931471805599453,
#  'vice': 0.6931471805599453,
#  'victor': 0.6931471805599453,
#  'vigorous': 0.6931471805599453,
#  'volunteer': 0.6931471805599453,
#  'voyage': 0.6931471805599453,
#  'w': 0.6931471805599453,
#  'walk': 0.6931471805599453,
#  'wanna': 0.6931471805599453,
#  'was': 0.6931471805599453,
#  'we': 0.6931471805599453,
#  'were': 0.6931471805599453,
#  'what': 0.6931471805599453,
#  'whatever': 0.6931471805599453,
#  'when': 0.6931471805599453,
#  'where': 0.6931471805599453,
#  'whether': 0.6931471805599453,
#  'which': 0.6931471805599453,
#  'who': 0.6931471805599453,
#  'whole': 0.6931471805599453,
#  'whom': 0.6931471805599453,
#  'will': 0.6931471805599453,
#  'wine': 0.6931471805599453,
#  'wish': 0.6931471805599453,
#  'wished': 0.6931471805599453,
#  'with': 0.6931471805599453,
#  'within': 0.6931471805599453,
#  'words': 0.6931471805599453,
#  'work': 0.6931471805599453,
#  'worker': 0.6931471805599453,
#  'would': 0.6931471805599453,
#  'wrecked': 0.6931471805599453,
#  'you': 0.6931471805599453,
#  'ziff': 0.6931471805599453}

# %%
tfidf = (df1/Idf)

# %%
tfidf
# Out:
#           a     about     above     abyss    accept  accomplished    across  \
# 0  0.027851  0.001857  0.001857  0.001857  0.003714      0.001857  0.001857
#
#         act     adams     after  ...    wished      with    within     words  \
# 0  0.001857  0.001857  0.001857  ...  0.001857  0.012997  0.001857  0.001857
#
#        work    worker     would   wrecked      you      ziff
# 0  0.003714  0.001857  0.001857  0.001857  0.00557  0.001857
#
# [1 rows x 396 columns]
